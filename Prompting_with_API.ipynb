# %% [markdown]
# <a href="https://colab.research.google.com/github/anshuman-dataverse/Gen_ai/blob/main/Prompting_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- applied-genai-header -->
# <div style="background: linear-gradient(135deg, #1e4b8f 0%, #2d6cb8 100%); color: white; padding: 24px; border-radius: 12px; font-family: 'Segoe UI', sans-serif; margin-bottom: 16px;">
#   <div style="font-size: 12px; opacity: 0.85; letter-spacing: 1.5px; text-transform: uppercase;">Applied Generative AI · IE 5373</div>
#   <h1 style="margin: 8px 0 4px 0; font-size: 28px; font-weight: 600;">Prompting with the OpenAI API</h1>
#   <div style="font-size: 14px; opacity: 0.9;">First steps: chat completions, system/user/assistant roles, parameters</div>
#   <div style="margin-top: 12px; font-size: 12px; opacity: 0.8;">Prof. Mohammad Dehghani · Northeastern University</div>
# </div>
#
# > **📌 Note on models.** This lab references specific LLM versions (e.g. `gpt-5`, `gpt-5-mini`).
# > Models update quickly — you are welcome (and encouraged) to swap in any newer OpenAI / Anthropic / Google model you have access to.
# > The default model is set in one place: `DEFAULT_CHAT_MODEL` inside `utils.py`. Change it there and every cell follows.

# %%
DEFAULT_CHAT_MODEL = "gpt-4"
DEFAULT_MINI_MODEL= "gpt-5-mini"
DEFAULT_EMBED_MODEL = "text-embedding-3-small"

# %%
# === Shared lab setup: utils.py + API key + sticky lab pill ===
# Downloads the shared utilities (pretty_print, model constants, key loader,
# lab_pill) from the AppliedGenAI repo so every notebook stays small and
# consistent. The API key is read from a Colab secret named OPENAI_API_KEY
# (set it once under Colab → 🔑 → "Notebook access" — same name in every lab).

import os
if not os.path.exists("utils.py"):
    # !wget -q https://raw.githubusercontent.com/mdehghani86/AppliedGenAI/main/utils.py -O utils.py

from utils import (
    pretty_print,
    DEFAULT_CHAT_MODEL,   # e.g. "gpt-5"  — main reasoning model
    DEFAULT_MINI_MODEL,   # e.g. "gpt-5-mini"  — cheaper / faster default
    DEFAULT_EMBED_MODEL,  # e.g. "text-embedding-3-small"
    get_openai_key,
    lab_pill,
)

lab_pill('Prompting with the OpenAI API')        # sticky banner so you always see which lab you're in
get_openai_key(verify=True)    # loads the key + pings OpenAI to confirm it works

# %% [markdown]
# # Applied Generative AI
# Instructor: Prof. Dehghani
# Welcome to the Applied Generative AI course. In this course, we will explore the foundations and applications of Generative AI using tools like OpenAI's API. By the end of this session, you will:
#
# 🟢 Understand how to set up and connect to OpenAI's API.
# 🌟 Learn about the roles (System, Assistant, User) in prompt design.
# ✨ Generate text, images, and vector embeddings programmatically.
# 🔧 Explore fine-tuning to customize AI models for specific tasks.
# Let’s get started with setting up the OpenAI API!

# %%
# Install the OpenAI Python SDK
# This library allows us to interact with OpenAI's API for text, images, and embeddings.
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.12/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (4.67.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (3.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2026.4.22)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.23.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->openai==0.28) (4.15.0)

# %%
from google.colab import userdata
import openai

# Retrieve the key from Colab secrets
openai.api_key = userdata.get('OPENAI_API_KEY')
# (api key handled by get_openai_key() in setup cell)

# Confirm the key was loaded (for debugging only; don’t print your real key in shared notebooks!)
print("Key loaded:", "Yes" if openai.api_key else "No")
# Out:
# Key loaded: Yes

# %% [markdown]
# 🎯 Prompt Playground: Understanding Roles
# In OpenAI's API, you interact with the model using roles, which define the flow of the conversation:
#
# ➡️ System: Sets the behavior and tone of the assistant (e.g., "You are a cheerful assistant.").
# ➡️ User: Represents the input or question from the user (e.g., "What is AI?").
# ➡️ Assistant: Automatically generated responses based on the system and user inputs.
# 💡 Why Roles Matter: Roles help control the assistant's personality and the quality of responses. For example:
#
# A system message like "You are a strict teacher" makes the assistant respond more formally.
# A system message like "You are a friendly chatbot" leads to casual responses.
# Let’s see how these roles work in the next cell!
#
# ## Example 1: Without Assistant Role

# %%
import openai
response = openai.ChatCompletion.create(
    model=DEFAULT_MINI_MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# # Example 2: With Assistant Role

# %%
import openai

# Demonstrating roles in OpenAI's API with the assistant role

# Define the conversation including a predefined assistant response
messages = [
    {"role": "system", "content": "You are a math tutor who explains problems step by step."},  # System role sets the behavior
    {"role": "user", "content": "Solve for x: 2x + 5 = 15"},  # User question
    {"role": "assistant", "content": "To solve for x: \n1. Subtract 5 from both sides: 2x = 10\n2. Divide both sides by 2: x = 5"}  # Predefined assistant response
]

# Send the conversation to the API
response = openai.ChatCompletion.create(
    model="gpt-4",  # Use the chosen model
    messages=messages  # Pass the conversation
)

# Print the assistant's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Step 1: Start with the original equation: 2x + 5 = 15.<br><br>Step 2: The goal is to isolate x, meaning we need to get rid of the '+5' on the side of the equation with 'x'. We handle this by doing the inverse operation. The inverse of '+5' is '-5'. To keep the equation balanced, we must subtract 5 from both sides.<br><br>So, we will subtract 5 from both sides: 2x + 5 - 5 = 15 - 5. This simplifies to 2x = 10.<br><br>Step 3: Now we still have to isolate x, this time getting rid of '*2'. The inverse operation of '*2' is '/2'. So we divide both sides of the equation by 2.<br><br>Divide by 2: 2x / 2 = 10 / 2, which simplifies to x = 5.<br><br>Step 4: Finally, we found that x is equal to 5. You can check this by substituting '5' for 'x' in the original equation and check if both sides of the equation remain equal. 2*5 + 5 = 15, which simplifies to 10 + 5 equals to 15 which is right.<br><br>So the solution to the problem: 2x + 5 = 15 is x = 5.</span>
#     </div>

# %% [markdown]
# 🧮 Hands-On

# %%
import openai
# ++++ Hands-On: Complete the Roles ++++

# Define the conversation using the role structure
messages = [
    {"role": "system", "content": "You are a math tutor who explains concepts clearly and step by step."},  # Complete the system role
    {"role": "user", "content": "How do you calculate the arithmetic mean of a set of numbers?"},  # Complete the user role
    {"role": "assistant", "content": "To calculate the arithmetic mean:\n"
                                "1. Add all the numbers in the set.\n"
                                "2. Divide the sum by the number of numbers.\n\n"
                                "For example, for 10, 20, and 30:\n"
                                "Mean = (10 + 20 + 30) / 3 = 60 / 3 = 20."
                                }
]

# Uncomment the code below after completing the placeholders
response = openai.ChatCompletion.create(
    model=DEFAULT_CHAT_MODEL,  # Specify the model
    messages=messages  # Pass the completed conversation
)
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">To calculate the arithmetic mean (often referred to simply as the "mean"), follow these steps:<br><br>Step 1: Add up all the numbers<br>Collect all the values from your data set and add them together. This will give you the sum of your data set. <br><br>For example, let's suppose you have the numbers 2, 4, 6, and 8.<br><br>So, you would add them together as such: 2 + 4 + 6 + 8 = 20.<br><br>Step 2: Count the numbers<br>The next step is to count how many numbers you have in your data set. This is called the "N". In our example, there are four numbers, so N = 4.<br><br>Step 3: Divide the Sum by N<br>The last step is to divide the sum of the numbers by the count of the numbers. <br><br>So in our example, the sum is 20 and the count is 4. So, 20 / 4 = 5.<br><br>So, the arithmetic mean of 2, 4, 6, and 8 is 5.</span>
#     </div>

# %% [markdown]
# Exercise 1: Simple Q&A with System + User Roles
# 👉 Task:
# Write a prompt that asks the assistant to behave like a science teacher, then ask it a science-related question.

# %%
import openai

# 🧠 Define your own roles and prompt below
messages = [
    {"role": "system", "content": "You are a science teacher who explain the concept clearly and correct, use  bullet point and paragraph combination."},
    {"role": "user", "content": "Ask your question here,'Explain how water evaporation works.'"}
]

# 🧠 Call the OpenAI API with your customized prompt
response = openai.ChatCompletion.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

# 🧠 Print the model's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Evaporation is one of the essential processes in the water cycle. It is the transformation of liquid water into its gaseous state, known as water vapor. This process can take place at any temperature, though it happens faster when the water is warmed. The detailed explanation of how water evaporation work is given below:<br><br>• Molecule Movement<br>   - Evaporation starts at a molecular level. Each molecule in a water body is in constant motion, and this motion will disturb neighbouring molecules, causing them to move as well. <br>   - The speed of the molecules depends upon the temperature. As the temperature increases, the speed of the molecules would also increase.<br><br>• Heat Energy<br>   - For evaporation to occur, water molecules need energy, typically derived from the surroundings or directly from the Sun. <br>   - When heat energy is introduced, water molecules become more active and thus move more quickly.<br><br>• Escape from the Surface<br>   - As molecules at the surface of the water body become heated, they gain enough energy to change their state from liquid to gas. This is when evaporation takes place.<br>   - Only the molecules with enough kinetic energy to overcome the liquid's surface tension can escape as a gas.<br>   - Note that evaporation is a surface phenomenon. The water evaporates from the surface area of bodies of water, such as oceans, rivers, or even a puddle or a dish of water.<br><br>• Cooling Effect<br>   - When water evaporates, it leaves behind cooler water molecules. Therefore, evaporation has a cooling effect. It is the same principle that causes your body to feel cooler when sweat evaporates from your skin.<br><br>• Into the Atmosphere<br>   - The water vapor will be released into the air where it becomes part of the atmosphere until it condenses, becoming liquid water again in the form of precipitation.<br>   - This allows the cycle, known as the water cycle or the hydrologic cycle, to continue.<br><br>In conclusion, evaporation is a crucial part of the water cycle, a complex process that brings us water, a vital resource for all forms of life. This transition of water from liquid to gas leads to changes in temperature and helps distribute heat globally.</span>
#     </div>

# %% [markdown]
# ### Observation
#
# The assistant's response closely follows the behavior defined in the **system role** (`"science teacher who explains clearly and correctly, uses bullet point and paragraph combination"`):
#
# - **Paragraph + bullet format:** The response opens with an introductory paragraph defining evaporation, then switches to bulleted sections (*Molecule Movement, Heat Energy, Escape from the Surface, Cooling Effect*) — exactly matching the requested *paragraph + bullet point* style.
# - **Teacher-like clarity:** The explanation is structured, uses simple scientific terms, and progresses logically from the molecular level → energy → phase change → real world effect, reflecting the *"science teacher"* persona.
# - **Topic faithfulness:** The output stays strictly on the user's question (*"Explain how water evaporation works"*) without drifting.
#
# **Conclusion:** The system role effectively controlled both the **format** (paragraph + bullets) and the **tone** (clear, instructional). This shows that well-defined system prompts can shape not just *what* the model says, but *how* it presents the information.

# %% [markdown]
# ✍️ Exercise 2: Give a prompt of your choice.
# 👉 Task:
# Now write your own custom prompt. Use any role, any question — be creative!

# %%
import openai


# Replace with your own prompt idea!
messages = [
    {"role": "system", "content": "You are a  gen ai engineer professor."},
    {"role": "user", "content": "How to become a best gen ai engineer?"}
]

response = openai.ChatCompletion.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Becoming a top-notch AI engineer involves a combination of education, skills and hands-on experience. Here are some crucial steps:<br><br>1. **Education**: You should have a strong base in computer science or a related field like data science, software engineering or applied mathematics. This usually involves obtaining a bachelor's degree. Many AI engineers also possess master's or doctorate degrees.<br><br>2. **Programming skills**: It is vital to have strong programming skills in languages like Python, Java, and R. Python is especially popular due to its simplicity and the fact that it's widely used in machine learning.<br><br>3. **Mathematics and Algorithms**: Gain a solid understanding of algebra, calculus, logic and algorithms. These principles are an integral part of AI programming.<br><br>4. **Machine Learning**: Get hands-on experience with machine learning. This can be through online courses or projects. You should be comfortable with various types of learning, including supervised, unsupervised, and reinforcement learning.<br><br>5. **Data Modeling and Evaluation**: Be proficient in data preprocessing, exploration, and visualization to understand and extract insights from complex dataset. Learn how to model data for prediction and how to evaluate the performance of those models.<br><br>6. **Learn Libraries and Frameworks**: Libraries such as TensorFlow, PyTorch, and Keras can simplify AI development and are extremely useful to learn. Familiarize yourself with these.<br><br>7. **Understand Neural Networks**: As an AI engineer, you should understand how to design, train, and optimize neural networks.<br><br>8. **Build Projects**: Developing hands-on projects will enable you to apply what you've learned and contribute to your portfolio.<br><br>9. **Keep up-to-date**: AI is always evolving. Therefore, it’s crucial to keep up with the latest advancements by reading research papers, attending conferences, or joining AI communities or forums.<br><br>10. **Internships and Work Experience**: If possible, try to gain experience in the field through internships or relevant job positions. Practical experience will provide you with invaluable insights that academic studies can't offer.<br><br>11. **Improve Soft Skills**: Communication and teamwork are valuable skills, especially if you would like to work in a multidisciplinary team or convey complex AI concepts to non-tech savvy individuals.<br><br>Remember, becoming the best takes time, patience, and continuous learning. Don't rush it. Focus on understanding the core concepts and practice as much as you can. Good luck!</span>
#     </div>

# %% [markdown]
# ### Observation
#
# The assistant's response reflects the **system role** (`"You are a gen ai engineer professor."`) and the **user query** (`"How to become a best gen ai engineer?"`):
#
# - **Professor-like structure:** The response is organized as a numbered curriculum (Education → Programming → Math → ML → Data Modeling → Frameworks → Neural Networks), mirroring how a *professor* would lay out a learning roadmap.
# - **Formatting:** Bolded headings (`**Education**`, `**Programming skills**`, etc.) followed by short explanations make the answer easy to scan — an instructional style suited to the persona.
# - **Scope drift:** Although the system role specified a *generative AI* engineer professor, the response leaned toward general **AI/ML engineering advice** (Python, TensorFlow, neural networks) rather than gen-AI–specific topics like LLMs, prompt engineering, fine-tuning, or RAG. This shows that vague system prompts can lead the model to generalize.
#
# **Conclusion:** The system role successfully shaped the **tone and structure** (professor-style roadmap), but because the prompt did not emphasize *generative AI* specifically, the content stayed broad. A more specific system prompt (e.g., *"You are a generative AI engineer professor specializing in LLMs and diffusion models"*) would produce a more focused answer.
# ````
